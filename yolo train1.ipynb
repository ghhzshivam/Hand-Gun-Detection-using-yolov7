# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Show GPU
# !nvidia-smi
# Out:
# Thu Sep  8 07:12:19 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# %cd drive/MyDrive/GunDetection/yolov7-main
# Out:
# /content/drive/MyDrive/GunDetection/yolov7-main

# %%
# !pwd
# Out:
# /content/drive/MyDrive/GunDetection/yolov7-main

# %%
#python train.py --workers 8 --device 0 --batch-size 32 --data data/custom.yaml file --ig 640 640 --cfg yolo training --weights --name runs>train>name  --hyperparameter file in data
# running py file with param
# !python train.py --workers 8 --device 0 --batch-size 16 --epochs 100 --data data/custom-data.yaml --img 640 640 --cfg cfg/training/custom-yolov7.yaml --weights yolov7.pt --name custom-yolov7x --hyp data/hyp.scratch.custom.yaml
# Out:
# YOLOR 🚀 2022-8-16 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/custom-yolov7.yaml', data='data/custom-data.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.custom.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='custom-yolov7x', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/custom-yolov7x4', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...
